# %% [markdown]
# ## This code is for Data Scraping of 'Tourist Destinations Worldwide' using multiple sources like Wikipedia, Google Search,Crowd sourcing and TripAdvisor website.

# %% [markdown]
# ### Group 14 : Radha Kamalapurkar - 12110009, Abhishek Maji - 12110101, Vini Chhajed - 12110080, Kumar Lalwani - 12110002

# %% [markdown]
# #### Initialize Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import re
import numpy as np
import time
import re

# %% [markdown]
# #### Scrape data(Destination_Name, City and Visitors_per_Year) from Wikipedia table using BeautifulSoup

# %%
wiki_url = 'https://en.wikipedia.org/wiki/List_of_most_visited_palaces_and_monuments'
table_id = "wikitable sortable"
response = requests.get(wiki_url)
soup = BeautifulSoup(response.text, 'html.parser')
lst_most_visited_dest = soup.find('table', attrs={"class":table_id})
lst = pd.read_html(str(lst_most_visited_dest))

# %%
df=pd.DataFrame(lst[0])

# %%
df = df.xs('National monuments by visitors per year', axis=1, drop_level=True)

# %%
df1=df[['Name', 'Country flag, city', 'Visitors per year']]

# %% [markdown]
# #### Create required dataframe from the scraped Wikipedia table

# %%
df1.rename(columns = {'Name':'Destination_Name','Country flag, city':'City', 'Visitors per year':'Visitors_per_year'}, inplace = True)
# Out:
# C:\Users\sanyo\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df1.reset_index(drop=True)
# Out:
#                                      Destination_Name              City  \
# 0                                      Forbidden City           Beijing
# 1                                St. Peter's Basilica      Vatican City
# 2                                Palace of Versailles        Versailles
# 3                                    Lincoln Memorial  Washington, D.C.
# 4               Colosseum-Forum-Palatine Hill Circuit              Rome
# 5                                           Parthenon            Athens
# 6                                           Taj Mahal              Agra
# 7                                        Eiffel Tower             Paris
# 8                                   Cologne Cathedral           Cologne
# 9                                     Peterhof Palace  Saint Petersburg
# 10                                    Łazienki Palace            Warsaw
# 11                          Vietnam Veterans Memorial  Washington, D.C.
# 12                              World War II Memorial  Washington, D.C.
# 13              Independence National Historical Park      Philadelphia
# 14                                    Sagrada Família         Barcelona
# 15                Statue of Liberty National Monument     New York City
# 16                                        Teotihuacán       Teotihuacán
# 17                        National Palace Museum[iii]            Taipei
# 18                                      Mysore Palace            Mysore
# 19                 Tsarskoe Selo State Museum-Reserve  Saint Petersburg
# 20                                            Pompeii            Naples
# 21                                      Musée d'Orsay             Paris
# 22                                     Wilanów Palace            Warsaw
# 23                                  Schönbrunn Palace            Vienna
# 24                                      Kazan Kremlin             Kazan
# 25                                    Tower of London            London
# 26                                           Alhambra           Granada
# 27                                       Chichén Itzá           Yucatán
# 28                                     Topkapı Palace          Istanbul
# 29                                 Chapultepec Castle       Mexico City
# 30                 Ciudad de las Artes y las Ciencias          Valencia
# 31                                    Statue of Unity          Kevadiya
# 32                                     Moscow Kremlin            Moscow
# 33          Battle of Stalingrad State Museum-Reserve         Volgograd
# 34                                              Tulum      Quintana Roo
# 35             Auschwitz-Birkenau Memorial and Museum          Oświęcim
# 36                                   Edinburgh Castle         Edinburgh
# 37                        Mosque–Cathedral of Córdoba           Córdoba
# 38                           Royal Alcázar of Seville           Seville
# 39                                       Wawel Castle            Kraków
# 40                                    Arc de Triomphe             Paris
# 41                             Royal Palace of Madrid            Madrid
# 42                              Neuschwanstein Castle    Hohenschwangau
# 43                                       Machu Picchu             Cusco
# 44  Castillo San Felipe del Morro (Old San Juan Hi...          San Juan
#
#    Visitors_per_year
# 0        17,000,000+
# 1           11000000
# 2            8100000
# 3            7804683
# 4            7650519
# 5            7200000
# 6            7090207
# 7            7000000
# 8            6000000
# 9            5245900
# 10           4966858
# 11           4719148
# 12           4652865
# 13           4576436
# 14           4500000
# 15           4335431
# 16           4070000
# 17           3900000
# 18           3861162
# 19           3694000
# 20           3646585
# 21           3300000
# 22           3115797
# 23           3050000
# 24           2893300
# 25           2858336
# 26           2760000
# 27           2740000
# 28           2720119
# 29           2661615
# 30           2637567
# 31        2,600,000+
# 32           2478622
# 33           2359300
# 34           2190000
# 35           2053000
# 36           2111578
# 37           1953133
# 38           1875744
# 39           1587999
# 40           1583260
# 41           1552481
# 42           1500000
# 43           1411276
# 44           1400000

# %% [markdown]
# #### Select random 14 Tourist Destinations from the DataFrame created above. We will be collecting data for these selected Tourist Destinations

# %%
filter_val=['Tower of London','Royal Palace of Madrid','Edinburgh Castle','Topkapı Palace','Forbidden City','Kazan Kremlin','Parthenon','Eiffel Tower','Cologne Cathedral','Sagrada Família','Machu Picchu','Alhambra','Moscow Kremlin','Chapultepec Castle']
df2=df1[df1.Destination_Name.isin(filter_val)]

# %% [markdown]
# #### Assign Destination_Id to each of the selected Tourist Destinations

# %%
data = {'Destination_Id': ['g186338-d187547','g187514-d190146','g186525-d187653','g293974-d294547','g294212-d319086','g298520-d321110','g189400-d198711','g187147-d188151','g187371-d192291','g187497-d190166','g294318-d668949','g187441-d191078','g298484-d300392','g150800-d183986'], 
        'Destination_Name': ['Tower of London','Royal Palace of Madrid','Edinburgh Castle','Topkapı Palace','Forbidden City','Kazan Kremlin','Parthenon','Eiffel Tower','Cologne Cathedral','Sagrada Família','Machu Picchu','Alhambra','Moscow Kremlin','Chapultepec Castle']
        }

destination_id_df = pd.DataFrame(data, columns= ['Destination_Id', 'Destination_Name'])

# %%
destination_id_df
# Out:
#      Destination_Id        Destination_Name
# 0   g186338-d187547         Tower of London
# 1   g187514-d190146  Royal Palace of Madrid
# 2   g186525-d187653        Edinburgh Castle
# 3   g293974-d294547          Topkapı Palace
# 4   g294212-d319086          Forbidden City
# 5   g298520-d321110           Kazan Kremlin
# 6   g189400-d198711               Parthenon
# 7   g187147-d188151            Eiffel Tower
# 8   g187371-d192291       Cologne Cathedral
# 9   g187497-d190166         Sagrada Família
# 10  g294318-d668949            Machu Picchu
# 11  g187441-d191078                Alhambra
# 12  g298484-d300392          Moscow Kremlin
# 13  g150800-d183986      Chapultepec Castle

# %% [markdown]
# #### Create another Data Frame with City and City_Id for each of the Tourist Destinations

# %%
data = {'City_Id': ['g186338','g187514','g186525','g293974','g294212','g298520','g189400','g187147','g187371','g187497','g294318','g187441','g298484','g150800'], 
        'City': ['London','Madrid','Edinburgh','Istanbul','Beijing','Kazan','Athens','Paris','Cologne','Barcelona','Cusco','Granada','Moscow','Mexico City']
        }

city_id = pd.DataFrame(data, columns= ['City_Id', 'City'])

# %% [markdown]
# #### Scrape data from Google Search to extract the temperature of each of the selected cities

# %%
city = ['London','Madrid','Edinburgh','Istanbul','Beijing','Kazan','Athens','Paris','Cologne','Barcelona','Cusco','Granada','Moscow','Mexico City']


avg_temp=[]
city_df=[]
  
for i in city:
    url = "https://google.com/search?q=weather+in+" + i
    request_result = requests.get( url )
    soup5 = BeautifulSoup( request_result.text , "html.parser" )
    temperature = soup5.find( "div" , class_='BNeawe' ).text 
    avg_temp.append(temperature)
    city_df.append(i)

# %% [markdown]
# #### Create a Data Frame with City and its Average Temperature

# %%
import pandas as pd
df9 = {'City':city_df,'City_Average_Temperature':avg_temp}
avg_temp = pd.DataFrame.from_dict(df9)

# %%
city_id
# Out:
#     City_Id         City
# 0   g186338       London
# 1   g187514       Madrid
# 2   g186525    Edinburgh
# 3   g293974     Istanbul
# 4   g294212      Beijing
# 5   g298520        Kazan
# 6   g189400       Athens
# 7   g187147        Paris
# 8   g187371      Cologne
# 9   g187497    Barcelona
# 10  g294318        Cusco
# 11  g187441      Granada
# 12  g298484       Moscow
# 13  g150800  Mexico City

# %%
city_id_df=pd.merge(city_id, avg_temp, on=["City"])

# %%
city_id_df
# Out:
#     City_Id         City City_Average_Temperature
# 0   g186338       London                     13°C
# 1   g187514       Madrid                     18°C
# 2   g186525    Edinburgh                     11°C
# 3   g293974     Istanbul                     19°C
# 4   g294212      Beijing                      9°C
# 5   g298520        Kazan                     12°C
# 6   g189400       Athens                     23°C
# 7   g187147        Paris                     14°C
# 8   g187371      Cologne                     12°C
# 9   g187497    Barcelona                     20°C
# 10  g294318        Cusco                     13°C
# 11  g187441      Granada                     20°C
# 12  g298484       Moscow                      8°C
# 13  g150800  Mexico City                     15°C

# %%
df3=pd.merge(df2, destination_id_df, on=["Destination_Name"])

# %% [markdown]
# #### Merge Data Frames to collate Destination and City level data

# %%
destination_df=pd.merge(df3, city_id_df, on=["City"])

# %%
destination_df
# Out:
#           Destination_Name         City Visitors_per_year   Destination_Id  \
# 0           Forbidden City      Beijing       17,000,000+  g294212-d319086
# 1                Parthenon       Athens           7200000  g189400-d198711
# 2             Eiffel Tower        Paris           7000000  g187147-d188151
# 3        Cologne Cathedral      Cologne           6000000  g187371-d192291
# 4          Sagrada Família    Barcelona           4500000  g187497-d190166
# 5            Kazan Kremlin        Kazan           2893300  g298520-d321110
# 6          Tower of London       London           2858336  g186338-d187547
# 7                 Alhambra      Granada           2760000  g187441-d191078
# 8           Topkapı Palace     Istanbul           2720119  g293974-d294547
# 9       Chapultepec Castle  Mexico City           2661615  g150800-d183986
# 10          Moscow Kremlin       Moscow           2478622  g298484-d300392
# 11        Edinburgh Castle    Edinburgh           2111578  g186525-d187653
# 12  Royal Palace of Madrid       Madrid           1552481  g187514-d190146
# 13            Machu Picchu        Cusco           1411276  g294318-d668949
#
#     City_Id City_Average_Temperature
# 0   g294212                      9°C
# 1   g189400                     23°C
# 2   g187147                     14°C
# 3   g187371                     12°C
# 4   g187497                     20°C
# 5   g298520                     12°C
# 6   g186338                     13°C
# 7   g187441                     20°C
# 8   g293974                     19°C
# 9   g150800                     15°C
# 10  g298484                      8°C
# 11  g186525                     11°C
# 12  g187514                     18°C
# 13  g294318                     13°C

# %% [markdown]
# #### Crowdsourcing - A Google Form is created to carry out a survey regarding the popularity of the Torist Destinations selected.This survey is used to find out which tourist destination is most preferred across the following criterias - Preferred Destination for Family Holiday,Preferred Destination for Solo Trip,Preferred Destination for a Holiday with Friends and Preferred Destination for a Holiday with Spouse/Partner

# %%
crowd_src=pd.read_csv('C:/Users/sanyo/OneDrive - Indian School of Business/Term1/DC/Office_Hour/get_phones_data/get_phones_data/Crowd_Source.csv',sep=',')

# %%
crowd_src
# Out:
#           Destination_Name Preferance_Family_Holiday_Destination  \
# 0                 Alhambra                                    4%
# 1       Chapultepec Castle                                    2%
# 2        Cologne Cathedral                                    4%
# 3         Edinburgh Castle                                   13%
# 4             Eiffel Tower                                   12%
# 5           Forbidden City                                    0%
# 6            Kazan Kremlin                                    0%
# 7             Machu Picchu                                    4%
# 8           Moscow Kremlin                                    4%
# 9            None of These                                    8%
# 10               Parthenon                                    8%
# 11  Royal Palace of Madrid                                    6%
# 12         Sagrada Família                                    2%
# 13          Topkapı Palace                                    8%
# 14         Tower of London                                   27%
#
#    Preferance_Solo_Trip_Destination Preferance_Friends_Holiday_Destination  \
# 0                                6%                                     0%
# 1                                4%                                     6%
# 2                                2%                                     0%
# 3                                8%                                     8%
# 4                                8%                                     4%
# 5                                4%                                     4%
# 6                                2%                                     4%
# 7                               21%                                    13%
# 8                                4%                                     0%
# 9                               17%                                     4%
# 10                               6%                                     6%
# 11                               4%                                    19%
# 12                               4%                                    19%
# 13                               0%                                     4%
# 14                              12%                                    10%
#
#    Preferance_Spouse/Partner_Holiday_Destination
# 0                                             2%
# 1                                             0%
# 2                                             4%
# 3                                             6%
# 4                                            47%
# 5                                             4%
# 6                                             0%
# 7                                             0%
# 8                                             4%
# 9                                             8%
# 10                                           14%
# 11                                            2%
# 12                                            2%
# 13                                            4%
# 14                                            4%

# %% [markdown]
# #### Merge the Crowd sourced data with the existing data frame for Destinations

# %%
destination_popularity_df=pd.merge(destination_df, crowd_src, on=["Destination_Name"])

# %%
destination_popularity_df
# Out:
#           Destination_Name         City Visitors_per_year   Destination_Id  \
# 0           Forbidden City      Beijing       17,000,000+  g294212-d319086
# 1                Parthenon       Athens           7200000  g189400-d198711
# 2             Eiffel Tower        Paris           7000000  g187147-d188151
# 3        Cologne Cathedral      Cologne           6000000  g187371-d192291
# 4          Sagrada Família    Barcelona           4500000  g187497-d190166
# 5            Kazan Kremlin        Kazan           2893300  g298520-d321110
# 6          Tower of London       London           2858336  g186338-d187547
# 7                 Alhambra      Granada           2760000  g187441-d191078
# 8           Topkapı Palace     Istanbul           2720119  g293974-d294547
# 9       Chapultepec Castle  Mexico City           2661615  g150800-d183986
# 10          Moscow Kremlin       Moscow           2478622  g298484-d300392
# 11        Edinburgh Castle    Edinburgh           2111578  g186525-d187653
# 12  Royal Palace of Madrid       Madrid           1552481  g187514-d190146
# 13            Machu Picchu        Cusco           1411276  g294318-d668949
#
#     City_Id City_Average_Temperature Preferance_Family_Holiday_Destination  \
# 0   g294212                      9°C                                    0%
# 1   g189400                     23°C                                    8%
# 2   g187147                     14°C                                   12%
# 3   g187371                     12°C                                    4%
# 4   g187497                     20°C                                    2%
# 5   g298520                     12°C                                    0%
# 6   g186338                     13°C                                   27%
# 7   g187441                     20°C                                    4%
# 8   g293974                     19°C                                    8%
# 9   g150800                     15°C                                    2%
# 10  g298484                      8°C                                    4%
# 11  g186525                     11°C                                   13%
# 12  g187514                     18°C                                    6%
# 13  g294318                     13°C                                    4%
#
#    Preferance_Solo_Trip_Destination Preferance_Friends_Holiday_Destination  \
# 0                                4%                                     4%
# 1                                6%                                     6%
# 2                                8%                                     4%
# 3                                2%                                     0%
# 4                                4%                                    19%
# 5                                2%                                     4%
# 6                               12%                                    10%
# 7                                6%                                     0%
# 8                                0%                                     4%
# 9                                4%                                     6%
# 10                               4%                                     0%
# 11                               8%                                     8%
# 12                               4%                                    19%
# 13                              21%                                    13%
#
#    Preferance_Spouse/Partner_Holiday_Destination
# 0                                             4%
# 1                                            14%
# 2                                            47%
# 3                                             4%
# 4                                             2%
# 5                                             0%
# 6                                             4%
# 7                                             2%
# 8                                             4%
# 9                                             0%
# 10                                            4%
# 11                                            6%
# 12                                            2%
# 13                                            0%

# %% [markdown]
# #### Scrape the following Tourist Destination data from TripAdvisor website for the selected destinations:Destination Description, Destination Type, Destination Rating, Destination Number of Reviews

# %%
driver = webdriver.Chrome(executable_path='C:/Users/sanyo/chromedriver.exe')
seed_url = "https://www.tripadvisor.in"
driver.get(seed_url)
time.sleep(10)
soup1 = BeautifulSoup(driver.page_source, 'html5lib')

k=[]
attraction_key_lst=[]
attraction_key_lst=["https://www.tripadvisor.in/Attraction_Review-g186338-d187547-Reviews-Tower_of_London-London_England.html","https://www.tripadvisor.in/Attraction_Review-g187514-d190146-Reviews-Royal_Palace_of_Madrid-Madrid.html","https://www.tripadvisor.in/Attraction_Review-g186525-d187653-Reviews-Edinburgh_Castle-Edinburgh_Scotland.html","https://www.tripadvisor.in/Attraction_Review-g293974-d294547-Reviews-Topkapi_Palace-Istanbul.html","https://www.tripadvisor.in/Attraction_Review-g294212-d319086-Reviews-Forbidden_City_The_Palace_Museum-Beijing.html","https://www.tripadvisor.in/Attraction_Review-g298520-d321110-Reviews-Kazan_Kremlin-Kazan_Republic_of_Tatarstan_Volga_District.html","https://www.tripadvisor.in/Attraction_Review-g189400-d198711-Reviews-Parthenon-Athens_Attica.html","https://www.tripadvisor.in/Attraction_Review-g187147-d188151-Reviews-Eiffel_Tower-Paris_Ile_de_France.html","https://www.tripadvisor.in/Attraction_Review-g187371-d192291-Reviews-Cologne_Cathedral-Cologne_North_Rhine_Westphalia.html","https://www.tripadvisor.in/Attraction_Review-g187497-d190166-Reviews-Basilica_of_the_Sagrada_Familia-Barcelona_Catalonia.html","https://www.tripadvisor.in/Attraction_Review-g294318-d668949-Reviews-Santuario_Historico_de_Machu_Picchu-Machu_Picchu_Sacred_Valley_Cusco_Region.html","https://www.tripadvisor.in/Attraction_Review-g150800-d183986-Reviews-Chapultepec_Castle-Mexico_City_Central_Mexico_and_Gulf_Coast.html","https://www.tripadvisor.in/Attraction_Review-g298484-d300392-Reviews-Moscow_Kremlin-Moscow_Central_Russia.html","https://www.tripadvisor.in/Attraction_Review-g187441-d191078-Reviews-The_Alhambra-Granada_Province_of_Granada_Andalucia.html"]
temp = []
temp1=[]
attraction_type = []
attraction_desc = []
attr_id=[]
attraction_rating=[]
attraction_rev=[]
cnt=0
cnt1=0


for k in attraction_key_lst:
    driver.get(k)
    time.sleep(10)
    soup1 = BeautifulSoup(driver.page_source, 'html.parser')  
      
    for name in soup1.find_all('div',attrs = {"class":"dYtkw"}):
        var1=name.text.strip()
        if name in [None]:
            attraction_desc.append("Not Available")
            #print(j)
            substring=k[45:60]
            attr_id.append(substring)
            
        else:
            attraction_desc.append(var1)
            #print(j)
            substring=k[45:60]
            attr_id.append(substring)
            
    for tp in soup1.find_all('div',attrs = {"class":"dlzPP"}):
        var2=tp.text.strip()
        if tp in [None]:
            temp.append("Not Available")
        else:
            temp.append(var2)
            
    for ar in soup1.find_all('div',attrs = {"class":"WlYyy cPsXC fksET cMKSg"}):
        var3=ar.text.strip()
        if ar in [None]:
            attraction_rating.append("Not Available")   
        else:
            attraction_rating.append(var3)
            
    for arev in soup1.find_all('span',attrs = {"class":"WlYyy diXIH bGusc dDKKM"}):
        var4=arev.text.strip()
        if arev in [None]:
            temp1.append("Not Available")
            
        else:
            temp1.append(var4)
            
attraction_type = [temp[cnt] for cnt in range(1,len(temp)) if cnt % 4 == 2]
attraction_rev = [temp1[cnt1] for cnt1 in range(1,len(temp1)) if cnt1 % 2 == 1]
               
driver.quit()

# %%
import pandas as pd
df4 = {'Destination_Id':attr_id,'Destination_Description':attraction_desc,'Destination_Type':attraction_type,'Destination_rating':attraction_rating,'Destination_Number_Of_Reviews':attraction_rev}
attraction_df = pd.DataFrame.from_dict(df4)

# %%
attraction_df
# Out:
#      Destination_Id                            Destination_Description  \
# 0   g186338-d187547  AboutDiscover London’s castle – a secure fortr...
# 1   g187514-d190146  AboutLuxurious, over-the-top rococo palace wit...
# 2   g186525-d187653  AboutEdinburgh Castle is a world famous icon o...
# 3   g293974-d294547  AboutThis enormous palace was the Imperial res...
# 4   g294212-d319086  AboutConsisting of more than 9,000 rooms and s...
# 5   g298520-d321110  AboutThe historic fortress dating back to the ...
# 6   g189400-d198711  AboutThe majestic ruins of an ancient Greek bu...
# 7   g187147-d188151  AboutCompleted in 1889, this colossal landmark...
# 8   g187371-d192291  AboutThis giant Gothic cathedral, which until ...
# 9   g187497-d190166  AboutThe Basilica of the Sagrada Familia is a ...
# 10  g294318-d668949  AboutSuggested durationMore than 3 hoursFeatur...
# 11  g150800-d183986  AboutThis 18th-century palace, known for its i...
# 12  g298484-d300392  AboutMoscow's most famous historical and polit...
# 13  g187441-d191078  AboutThe second most visited site in Europe: t...
#
#                                      Destination_Type Destination_rating  \
# 0     Historic Sites • Points of Interest & Landmarks                4.5
# 1            Historic Sites • Architectural Buildings                4.5
# 2                                             Castles                4.5
# 3                                     History Museums                4.5
# 4   Speciality Museums • Architectural Buildings •...                4.5
# 5   Speciality Museums • Historic Sites • Architec...                5.0
# 6   Historic Sites • Ancient Ruins • Architectural...                4.5
# 7   Points of Interest & Landmarks • Observation D...                4.5
# 8   Points of Interest & Landmarks • Architectural...                4.5
# 9   Points of Interest & Landmarks • Architectural...                4.5
# 10                     Historic Sites • Ancient Ruins                5.0
# 11                                            Castles                4.5
# 12                Speciality Museums • Historic Sites                4.5
# 13  Historic Sites • Architectural Buildings • Cas...                4.5
#
#    Destination_Number_Of_Reviews
# 0                 65,841 reviews
# 1                 34,644 reviews
# 2                 51,473 reviews
# 3                 27,302 reviews
# 4                 14,097 reviews
# 5                  3,807 reviews
# 6                 16,878 reviews
# 7               1,40,408 reviews
# 8                 21,850 reviews
# 9               1,63,992 reviews
# 10                19,605 reviews
# 11                10,628 reviews
# 12                 7,900 reviews
# 13                42,345 reviews

# %% [markdown]
# #### Scrape the following Hotels data from TripAdvisor website for hotels in cities for the selected destinations:Hotel Name,Hotel Rating,Hotel Number of Reviews

# %%
driver = webdriver.Chrome(executable_path='C:/Users/sanyo/chromedriver.exe')
seed_url = "https://www.tripadvisor.in"
driver.get(seed_url)
time.sleep(10)
soup2 = BeautifulSoup(driver.page_source, 'html.parser')

city_key_lst=['-g186338-London_England','-g187514-Madrid','-g186525-Edinburgh_Scotland','-g293974-Istanbul','-g294212-Beijing','-g298520-Kazan_Republic_of_Tatarstan_Volga_District','-g189400-Athens_Attica','-g187147-Paris_Ile_de_France','-g187371-Cologne_North_Rhine_Westphalia','-g187497-Barcelona_Catalonia','-g294318-Machu_Picchu_Sacred_Valley_Cusco_Region','-g187441-Granada_Province_of_Granada_Andalucia','-g298484-Moscow_Central_Russia','-g150800-Mexico_City_Central_Mexico_and_Gulf_Coast']

Hotel = []
Hotel_url=[]
for name in soup2.find_all('a',{"href":"/Hotels"}):
    Hotel.append(name.text.strip())

for i in city_key_lst:
    Hotel_path=seed_url+'/'+Hotel[0]+i+'-Hotels.html'
    Hotel_url.append(Hotel_path)

j_lst=[]
hotel = []
loc_id = []
ratings = []
reviews = []

for j in Hotel_url:
    driver.get(j)
    time.sleep(10)
    soup2 = BeautifulSoup(driver.page_source, 'html.parser')
        
    
    for name in soup2.find_all('div',attrs = {"class":"listing_title"}):
        var5=name.text.strip()
        if name in [None]:
            hotel.append("Not Available")
            #print(j)
            substring=j[34:41]
            loc_id.append(substring)
            
        else:
            hotel.append(var5)
            #print(j)
            substring=j[34:41]
            loc_id.append(substring)
               
    for rating in soup2.find_all('a',attrs = {'class':'ui_bubble_rating'}):
        var6=rating['alt']
        if rating in [None]:
            ratings.append("Not Available")
        else:
            ratings.append(var6)       

    
    for review in soup2.find_all('a',{'class':'review_count'}):
        var7=review.text.strip()
        if review in [None]:
            reviews.append("Not Available")
        else:
            reviews.append(var7)
        
    
driver.quit()

# %%
import pandas as pd
df5 = {'City_Id':loc_id,'Hotel':hotel,'Hotel_Ratings':ratings,'Hotel_No_of_Reviews':reviews}
hotel_df = pd.DataFrame.from_dict(df5)

# %%
hotel_df
# Out:
#      City_Id                                         Hotel     Hotel_Ratings  \
# 0    g186338                 Sponsored      Bermonds Locke  4.5 of 5 bubbles
# 1    g186338                    The Resident Covent Garden    5 of 5 bubbles
# 2    g186338                               The Tower Hotel    4 of 5 bubbles
# 3    g186338            Leonardo Royal London Tower Bridge  4.5 of 5 bubbles
# 4    g186338  Montcalm Royal London House - City of London    5 of 5 bubbles
# ..       ...                                           ...               ...
# 440  g150800        Hilton Garden Inn Mexico City Santa Fe    4 of 5 bubbles
# 441  g150800             City Express Plus Insurgentes Sur    4 of 5 bubbles
# 442  g150800                             Hotel Ritz Mexico  3.5 of 5 bubbles
# 443  g150800      City Express Aeropuerto Ciudad de Mexico  3.5 of 5 bubbles
# 444  g150800                              Hotel Aeropuerto  3.5 of 5 bubbles
#
#     Hotel_No_of_Reviews
# 0            98 reviews
# 1           783 reviews
# 2        11,087 reviews
# 3         1,545 reviews
# 4         2,574 reviews
# ..                  ...
# 440         132 reviews
# 441       1,102 reviews
# 442         273 reviews
# 443         227 reviews
# 444          65 reviews
#
# [445 rows x 4 columns]

# %% [markdown]
# #### Merge the Tourist Destination data and Hotels data

# %%
destination_attraction=pd.merge(destination_popularity_df, attraction_df, on=["Destination_Id"])

# %%
destination_attraction
# Out:
#           Destination_Name         City Visitors_per_year   Destination_Id  \
# 0           Forbidden City      Beijing       17,000,000+  g294212-d319086
# 1                Parthenon       Athens           7200000  g189400-d198711
# 2             Eiffel Tower        Paris           7000000  g187147-d188151
# 3        Cologne Cathedral      Cologne           6000000  g187371-d192291
# 4          Sagrada Família    Barcelona           4500000  g187497-d190166
# 5            Kazan Kremlin        Kazan           2893300  g298520-d321110
# 6          Tower of London       London           2858336  g186338-d187547
# 7                 Alhambra      Granada           2760000  g187441-d191078
# 8           Topkapı Palace     Istanbul           2720119  g293974-d294547
# 9       Chapultepec Castle  Mexico City           2661615  g150800-d183986
# 10          Moscow Kremlin       Moscow           2478622  g298484-d300392
# 11        Edinburgh Castle    Edinburgh           2111578  g186525-d187653
# 12  Royal Palace of Madrid       Madrid           1552481  g187514-d190146
# 13            Machu Picchu        Cusco           1411276  g294318-d668949
#
#     City_Id City_Average_Temperature Preferance_Family_Holiday_Destination  \
# 0   g294212                      9°C                                    0%
# 1   g189400                     23°C                                    8%
# 2   g187147                     14°C                                   12%
# 3   g187371                     12°C                                    4%
# 4   g187497                     20°C                                    2%
# 5   g298520                     12°C                                    0%
# 6   g186338                     13°C                                   27%
# 7   g187441                     20°C                                    4%
# 8   g293974                     19°C                                    8%
# 9   g150800                     15°C                                    2%
# 10  g298484                      8°C                                    4%
# 11  g186525                     11°C                                   13%
# 12  g187514                     18°C                                    6%
# 13  g294318                     13°C                                    4%
#
#    Preferance_Solo_Trip_Destination Preferance_Friends_Holiday_Destination  \
# 0                                4%                                     4%
# 1                                6%                                     6%
# 2                                8%                                     4%
# 3                                2%                                     0%
# 4                                4%                                    19%
# 5                                2%                                     4%
# 6                               12%                                    10%
# 7                                6%                                     0%
# 8                                0%                                     4%
# 9                                4%                                     6%
# 10                               4%                                     0%
# 11                               8%                                     8%
# 12                               4%                                    19%
# 13                              21%                                    13%
#
#    Preferance_Spouse/Partner_Holiday_Destination  \
# 0                                             4%
# 1                                            14%
# 2                                            47%
# 3                                             4%
# 4                                             2%
# 5                                             0%
# 6                                             4%
# 7                                             2%
# 8                                             4%
# 9                                             0%
# 10                                            4%
# 11                                            6%
# 12                                            2%
# 13                                            0%
#
#                               Destination_Description  \
# 0   AboutConsisting of more than 9,000 rooms and s...
# 1   AboutThe majestic ruins of an ancient Greek bu...
# 2   AboutCompleted in 1889, this colossal landmark...
# 3   AboutThis giant Gothic cathedral, which until ...
# 4   AboutThe Basilica of the Sagrada Familia is a ...
# 5   AboutThe historic fortress dating back to the ...
# 6   AboutDiscover London’s castle – a secure fortr...
# 7   AboutThe second most visited site in Europe: t...
# 8   AboutThis enormous palace was the Imperial res...
# 9   AboutThis 18th-century palace, known for its i...
# 10  AboutMoscow's most famous historical and polit...
# 11  AboutEdinburgh Castle is a world famous icon o...
# 12  AboutLuxurious, over-the-top rococo palace wit...
# 13  AboutSuggested durationMore than 3 hoursFeatur...
#
#                                      Destination_Type Destination_rating  \
# 0   Speciality Museums • Architectural Buildings •...                4.5
# 1   Historic Sites • Ancient Ruins • Architectural...                4.5
# 2   Points of Interest & Landmarks • Observation D...                4.5
# 3   Points of Interest & Landmarks • Architectural...                4.5
# 4   Points of Interest & Landmarks • Architectural...                4.5
# 5   Speciality Museums • Historic Sites • Architec...                5.0
# 6     Historic Sites • Points of Interest & Landmarks                4.5
# 7   Historic Sites • Architectural Buildings • Cas...                4.5
# 8                                     History Museums                4.5
# 9                                             Castles                4.5
# 10                Speciality Museums • Historic Sites                4.5
# 11                                            Castles                4.5
# 12           Historic Sites • Architectural Buildings                4.5
# 13                     Historic Sites • Ancient Ruins                5.0
#
#    Destination_Number_Of_Reviews
# 0                 14,097 reviews
# 1                 16,878 reviews
# 2               1,40,408 reviews
# 3                 21,850 reviews
# 4               1,63,992 reviews
# 5                  3,807 reviews
# 6                 65,841 reviews
# 7                 42,345 reviews
# 8                 27,302 reviews
# 9                 10,628 reviews
# 10                 7,900 reviews
# 11                51,473 reviews
# 12                34,644 reviews
# 13                19,605 reviews

# %% [markdown]
# #### Scrape the following Destinations data from TripAdvisor website for the selected destinations:Destination Reviews

# %%
driver = webdriver.Chrome(executable_path='C:/Users/sanyo/chromedriver.exe')
seed_url = "https://www.tripadvisor.in"
driver.get(seed_url)
time.sleep(10)
soup3 = BeautifulSoup(driver.page_source, 'html.parser')

j=[]
attraction_key_lst=[]
attraction_key_lst=["https://www.tripadvisor.in/Attraction_Review-g186338-d187547-Reviews-Tower_of_London-London_England.html","https://www.tripadvisor.in/Attraction_Review-g187514-d190146-Reviews-Royal_Palace_of_Madrid-Madrid.html","https://www.tripadvisor.in/Attraction_Review-g186525-d187653-Reviews-Edinburgh_Castle-Edinburgh_Scotland.html","https://www.tripadvisor.in/Attraction_Review-g293974-d294547-Reviews-Topkapi_Palace-Istanbul.html","https://www.tripadvisor.in/Attraction_Review-g294212-d319086-Reviews-Forbidden_City_The_Palace_Museum-Beijing.html","https://www.tripadvisor.in/Attraction_Review-g298520-d321110-Reviews-Kazan_Kremlin-Kazan_Republic_of_Tatarstan_Volga_District.html","https://www.tripadvisor.in/Attraction_Review-g189400-d198711-Reviews-Parthenon-Athens_Attica.html","https://www.tripadvisor.in/Attraction_Review-g187147-d188151-Reviews-Eiffel_Tower-Paris_Ile_de_France.html","https://www.tripadvisor.in/Attraction_Review-g187371-d192291-Reviews-Cologne_Cathedral-Cologne_North_Rhine_Westphalia.html","https://www.tripadvisor.in/Attraction_Review-g187497-d190166-Reviews-Basilica_of_the_Sagrada_Familia-Barcelona_Catalonia.html","https://www.tripadvisor.in/Attraction_Review-g294318-d668949-Reviews-Santuario_Historico_de_Machu_Picchu-Machu_Picchu_Sacred_Valley_Cusco_Region.html","https://www.tripadvisor.in/Attraction_Review-g150800-d183986-Reviews-Chapultepec_Castle-Mexico_City_Central_Mexico_and_Gulf_Coast.html","https://www.tripadvisor.in/Attraction_Review-g298484-d300392-Reviews-Moscow_Kremlin-Moscow_Central_Russia.html","https://www.tripadvisor.in/Attraction_Review-g187441-d191078-Reviews-The_Alhambra-Granada_Province_of_Granada_Andalucia.html"]
attraction_review=[]
attr_id=[]


for j in attraction_key_lst:
    driver.get(j)
    time.sleep(10)
    soup3 = BeautifulSoup(driver.page_source, 'html.parser')  
    
            
    for attr_rev in soup3.find_all('div',attrs = {"class":"duhwe _T bOlcm"}):
        var8=attr_rev.text.strip()
        if attr_rev in [None]:
            attraction_review.append("Not Available")
            substring=j[45:60]
            attr_id.append(substring)
            
        else:
            attraction_review.append(var8)
            substring=j[45:60]
            attr_id.append(substring)
                
driver.quit()

# %%
import pandas as pd
df6 = {'Destination_Id':attr_id,'Destination_Top_Reviews':attraction_review}
destination_review = pd.DataFrame.from_dict(df6)

# %%
destination_review
# Out:
#       Destination_Id                            Destination_Top_Reviews
# 0    g186338-d187547  Wonderful attraction especially seeing the Cro...
# 1    g186338-d187547  Beefeater tour is a must if you visit. laurenc...
# 2    g186338-d187547  A brilliant day out the beefeater tour is well...
# 3    g186338-d187547  As mentioned in a previous review. We took the...
# 4    g186338-d187547  Great visit here with teen and a 10 year old. ...
# ..               ...                                                ...
# 133  g187441-d191078  The Alhambra in October is an enchanting seque...
# 134  g187441-d191078  I looked at pictures online before the trip, b...
# 135  g187441-d191078  Amazing !! We opted for a guide her name is Ma...
# 136  g187441-d191078  Stunning, amazing views and so much history. A...
# 137  g187441-d191078  Over the top security, had to show our identit...
#
# [138 rows x 2 columns]

# %% [markdown]
# #### Merge the additional Destinations data

# %%
destination_attraction_df=pd.merge(destination_attraction, destination_review, on=["Destination_Id"])

# %%
destination_attraction_df
# Out:
#     Destination_Name     City Visitors_per_year   Destination_Id  City_Id  \
# 0     Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 1     Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 2     Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 3     Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 4     Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# ..               ...      ...               ...              ...      ...
# 133     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 134     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 135     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 136     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 137     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
#
#     City_Average_Temperature Preferance_Family_Holiday_Destination  \
# 0                        9°C                                    0%
# 1                        9°C                                    0%
# 2                        9°C                                    0%
# 3                        9°C                                    0%
# 4                        9°C                                    0%
# ..                       ...                                   ...
# 133                     13°C                                    4%
# 134                     13°C                                    4%
# 135                     13°C                                    4%
# 136                     13°C                                    4%
# 137                     13°C                                    4%
#
#     Preferance_Solo_Trip_Destination Preferance_Friends_Holiday_Destination  \
# 0                                 4%                                     4%
# 1                                 4%                                     4%
# 2                                 4%                                     4%
# 3                                 4%                                     4%
# 4                                 4%                                     4%
# ..                               ...                                    ...
# 133                              21%                                    13%
# 134                              21%                                    13%
# 135                              21%                                    13%
# 136                              21%                                    13%
# 137                              21%                                    13%
#
#     Preferance_Spouse/Partner_Holiday_Destination  \
# 0                                              4%
# 1                                              4%
# 2                                              4%
# 3                                              4%
# 4                                              4%
# ..                                            ...
# 133                                            0%
# 134                                            0%
# 135                                            0%
# 136                                            0%
# 137                                            0%
#
#                                Destination_Description  \
# 0    AboutConsisting of more than 9,000 rooms and s...
# 1    AboutConsisting of more than 9,000 rooms and s...
# 2    AboutConsisting of more than 9,000 rooms and s...
# 3    AboutConsisting of more than 9,000 rooms and s...
# 4    AboutConsisting of more than 9,000 rooms and s...
# ..                                                 ...
# 133  AboutSuggested durationMore than 3 hoursFeatur...
# 134  AboutSuggested durationMore than 3 hoursFeatur...
# 135  AboutSuggested durationMore than 3 hoursFeatur...
# 136  AboutSuggested durationMore than 3 hoursFeatur...
# 137  AboutSuggested durationMore than 3 hoursFeatur...
#
#                                       Destination_Type Destination_rating  \
# 0    Speciality Museums • Architectural Buildings •...                4.5
# 1    Speciality Museums • Architectural Buildings •...                4.5
# 2    Speciality Museums • Architectural Buildings •...                4.5
# 3    Speciality Museums • Architectural Buildings •...                4.5
# 4    Speciality Museums • Architectural Buildings •...                4.5
# ..                                                 ...                ...
# 133                     Historic Sites • Ancient Ruins                5.0
# 134                     Historic Sites • Ancient Ruins                5.0
# 135                     Historic Sites • Ancient Ruins                5.0
# 136                     Historic Sites • Ancient Ruins                5.0
# 137                     Historic Sites • Ancient Ruins                5.0
#
#     Destination_Number_Of_Reviews  \
# 0                  14,097 reviews
# 1                  14,097 reviews
# 2                  14,097 reviews
# 3                  14,097 reviews
# 4                  14,097 reviews
# ..                            ...
# 133                19,605 reviews
# 134                19,605 reviews
# 135                19,605 reviews
# 136                19,605 reviews
# 137                19,605 reviews
#
#                                Destination_Top_Reviews
# 0    Consisting of more than 9,000 rooms and spread...
# 1    Every time I'm in Beijing I try to visit the F...
# 2    The Forbidden City is an amazing place that yo...
# 3    It is a quintessential display of Chinese cult...
# 4    The area is astonishing but we met some scamme...
# ..                                                 ...
# 133  Amazing trip, amazing place in Machu Picchu, C...
# 134  It is a great sight well worth the visit. The ...
# 135  This is the reason we came to Peru and it did ...
# 136  What a great day in Machu Picchu!!!A magic pla...
# 137  Thank you for visiting Machu Picchu. We hope y...
#
# [138 rows x 15 columns]

# %% [markdown]
# #### Again, merge the Tourist Destination data and Hotels data after addition of reviews to Tourist Destination data

# %%
destination_hotel_attraction_df=pd.merge(destination_attraction_df, hotel_df, on=["City_Id"])

# %%
destination_hotel_attraction_df
# Out:
#      Destination_Name     City Visitors_per_year   Destination_Id  City_Id  \
# 0      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 1      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 2      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 3      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 4      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# ...               ...      ...               ...              ...      ...
# 4381     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4382     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4383     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4384     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4385     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
#
#      City_Average_Temperature Preferance_Family_Holiday_Destination  \
# 0                         9°C                                    0%
# 1                         9°C                                    0%
# 2                         9°C                                    0%
# 3                         9°C                                    0%
# 4                         9°C                                    0%
# ...                       ...                                   ...
# 4381                     13°C                                    4%
# 4382                     13°C                                    4%
# 4383                     13°C                                    4%
# 4384                     13°C                                    4%
# 4385                     13°C                                    4%
#
#      Preferance_Solo_Trip_Destination Preferance_Friends_Holiday_Destination  \
# 0                                  4%                                     4%
# 1                                  4%                                     4%
# 2                                  4%                                     4%
# 3                                  4%                                     4%
# 4                                  4%                                     4%
# ...                               ...                                    ...
# 4381                              21%                                    13%
# 4382                              21%                                    13%
# 4383                              21%                                    13%
# 4384                              21%                                    13%
# 4385                              21%                                    13%
#
#      Preferance_Spouse/Partner_Holiday_Destination  \
# 0                                               4%
# 1                                               4%
# 2                                               4%
# 3                                               4%
# 4                                               4%
# ...                                            ...
# 4381                                            0%
# 4382                                            0%
# 4383                                            0%
# 4384                                            0%
# 4385                                            0%
#
#                                 Destination_Description  \
# 0     AboutConsisting of more than 9,000 rooms and s...
# 1     AboutConsisting of more than 9,000 rooms and s...
# 2     AboutConsisting of more than 9,000 rooms and s...
# 3     AboutConsisting of more than 9,000 rooms and s...
# 4     AboutConsisting of more than 9,000 rooms and s...
# ...                                                 ...
# 4381  AboutSuggested durationMore than 3 hoursFeatur...
# 4382  AboutSuggested durationMore than 3 hoursFeatur...
# 4383  AboutSuggested durationMore than 3 hoursFeatur...
# 4384  AboutSuggested durationMore than 3 hoursFeatur...
# 4385  AboutSuggested durationMore than 3 hoursFeatur...
#
#                                        Destination_Type Destination_rating  \
# 0     Speciality Museums • Architectural Buildings •...                4.5
# 1     Speciality Museums • Architectural Buildings •...                4.5
# 2     Speciality Museums • Architectural Buildings •...                4.5
# 3     Speciality Museums • Architectural Buildings •...                4.5
# 4     Speciality Museums • Architectural Buildings •...                4.5
# ...                                                 ...                ...
# 4381                     Historic Sites • Ancient Ruins                5.0
# 4382                     Historic Sites • Ancient Ruins                5.0
# 4383                     Historic Sites • Ancient Ruins                5.0
# 4384                     Historic Sites • Ancient Ruins                5.0
# 4385                     Historic Sites • Ancient Ruins                5.0
#
#      Destination_Number_Of_Reviews  \
# 0                   14,097 reviews
# 1                   14,097 reviews
# 2                   14,097 reviews
# 3                   14,097 reviews
# 4                   14,097 reviews
# ...                            ...
# 4381                19,605 reviews
# 4382                19,605 reviews
# 4383                19,605 reviews
# 4384                19,605 reviews
# 4385                19,605 reviews
#
#                                 Destination_Top_Reviews  \
# 0     Consisting of more than 9,000 rooms and spread...
# 1     Consisting of more than 9,000 rooms and spread...
# 2     Consisting of more than 9,000 rooms and spread...
# 3     Consisting of more than 9,000 rooms and spread...
# 4     Consisting of more than 9,000 rooms and spread...
# ...                                                 ...
# 4381  Thank you for visiting Machu Picchu. We hope y...
# 4382  Thank you for visiting Machu Picchu. We hope y...
# 4383  Thank you for visiting Machu Picchu. We hope y...
# 4384  Thank you for visiting Machu Picchu. We hope y...
# 4385  Thank you for visiting Machu Picchu. We hope y...
#
#                                                   Hotel     Hotel_Ratings  \
# 0     Sponsored      Artyzen Habitat Dongzhimen Beijing    5 of 5 bubbles
# 1                      China World Summit Wing, Beijing    5 of 5 bubbles
# 2                                    Shangri-La Beijing    5 of 5 bubbles
# 3                             The Bulgari Hotel Beijing    5 of 5 bubbles
# 4                       Hotel Jen Beijing by Shangri-La    5 of 5 bubbles
# ...                                                 ...               ...
# 4381                                 Machupicchu Packer  3.5 of 5 bubbles
# 4382                               Quilla Ecologico Inn  4.5 of 5 bubbles
# 4383                           Hotel Ferre Machu Picchu    4 of 5 bubbles
# 4384                                Gran Paititi Hostal    2 of 5 bubbles
# 4385     Sanctuary Lodge, A Belmond Hotel, Machu Picchu  4.5 of 5 bubbles
#
#      Hotel_No_of_Reviews
# 0             95 reviews
# 1          3,214 reviews
# 2          8,489 reviews
# 3            255 reviews
# 4          2,333 reviews
# ...                  ...
# 4381          55 reviews
# 4382          10 reviews
# 4383         408 reviews
# 4384          18 reviews
# 4385       2,671 reviews
#
# [4386 rows x 18 columns]

# %% [markdown]
# #### Scrape the following Restaurants data from TripAdvisor website for restaurants in cities for the selected destinations:Restaurant Name

# %%
driver = webdriver.Chrome(executable_path='C:/Users/sanyo/chromedriver.exe')
seed_url = "https://www.tripadvisor.in"
driver.get(seed_url)
time.sleep(10)
soup4 = BeautifulSoup(driver.page_source, 'html5lib')

city_key_lst=['-g186338-London_England','-g187514-Madrid','-g186525-Edinburgh_Scotland','-g293974-Istanbul','-g294212-Beijing','-g298520-Kazan_Republic_of_Tatarstan_Volga_District','-g189400-Athens_Attica','-g187147-Paris_Ile_de_France','-g187371-Cologne_North_Rhine_Westphalia','-g187497-Barcelona_Catalonia','-g294318-Machu_Picchu_Sacred_Valley_Cusco_Region','-g187441-Granada_Province_of_Granada_Andalucia','-g298484-Moscow_Central_Russia','-g150800-Mexico_City_Central_Mexico_and_Gulf_Coast']

Restaurant = []
Restaurant_url=[]
for name in soup4.find_all('a',{"href":"/Restaurants"}):
    Restaurant.append(name.text.strip())

for i in city_key_lst:
    Restaurant_path=seed_url+'/'+Restaurant[0]+i+'.html'
    Restaurant_url.append(Restaurant_path)

restaurant = []
loc_id = []
res_rev = []

for j in Restaurant_url:
    driver.get(j)
    time.sleep(10)
    soup4 = BeautifulSoup(driver.page_source, 'html.parser')
        
    
    for name in soup4.find_all('div',attrs = {"class":"OhCyu"}):
        var9=name.text.strip()
        if name in [None]:
            restaurant.append("Not Available")
            #print(j)
            substring=j[39:46]
            loc_id.append(substring)
            
        else:
            restaurant.append(var9)
            #print(j)
            substring=j[39:46]
            loc_id.append(substring)  
                        
driver.quit()

# %%
import pandas as pd
df8 = {'City_Id':loc_id,'Top_Restaurants':restaurant}
restaurant_df = pd.DataFrame.from_dict(df8)

# %%
restaurant_df
# Out:
#      City_Id                           Top_Restaurants
# 0    g186338  Steak & Co. Garrick Street Covent Garden
# 1    g186338                     1. Bonoo Indian Tapas
# 2    g186338                                  2. Hibox
# 3    g186338                            3. Indian Room
# 4    g186338                                  4. Iznik
# ..       ...                                       ...
# 472  g150800               27. Dalis pizzeria italiana
# 473  g150800                   28. Sonora Grill Amores
# 474  g150800                     29. Salute Food & Bar
# 475  g150800                   30. Sonora Grill Miyana
# 476  g150800                        La 3a Ronda Miyana
#
# [477 rows x 2 columns]

# %% [markdown]
# #### Merge Tourist Destination and Restaurants data

# %%
destination_restaurant_attraction_df=pd.merge(destination_attraction_df, restaurant_df, on=["City_Id"])

# %%
destination_restaurant_attraction_df
# Out:
#      Destination_Name     City Visitors_per_year   Destination_Id  City_Id  \
# 0      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 1      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 2      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 3      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 4      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# ...               ...      ...               ...              ...      ...
# 4689     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4690     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4691     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4692     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4693     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
#
#      City_Average_Temperature Preferance_Family_Holiday_Destination  \
# 0                         9°C                                    0%
# 1                         9°C                                    0%
# 2                         9°C                                    0%
# 3                         9°C                                    0%
# 4                         9°C                                    0%
# ...                       ...                                   ...
# 4689                     13°C                                    4%
# 4690                     13°C                                    4%
# 4691                     13°C                                    4%
# 4692                     13°C                                    4%
# 4693                     13°C                                    4%
#
#      Preferance_Solo_Trip_Destination Preferance_Friends_Holiday_Destination  \
# 0                                  4%                                     4%
# 1                                  4%                                     4%
# 2                                  4%                                     4%
# 3                                  4%                                     4%
# 4                                  4%                                     4%
# ...                               ...                                    ...
# 4689                              21%                                    13%
# 4690                              21%                                    13%
# 4691                              21%                                    13%
# 4692                              21%                                    13%
# 4693                              21%                                    13%
#
#      Preferance_Spouse/Partner_Holiday_Destination  \
# 0                                               4%
# 1                                               4%
# 2                                               4%
# 3                                               4%
# 4                                               4%
# ...                                            ...
# 4689                                            0%
# 4690                                            0%
# 4691                                            0%
# 4692                                            0%
# 4693                                            0%
#
#                                 Destination_Description  \
# 0     AboutConsisting of more than 9,000 rooms and s...
# 1     AboutConsisting of more than 9,000 rooms and s...
# 2     AboutConsisting of more than 9,000 rooms and s...
# 3     AboutConsisting of more than 9,000 rooms and s...
# 4     AboutConsisting of more than 9,000 rooms and s...
# ...                                                 ...
# 4689  AboutSuggested durationMore than 3 hoursFeatur...
# 4690  AboutSuggested durationMore than 3 hoursFeatur...
# 4691  AboutSuggested durationMore than 3 hoursFeatur...
# 4692  AboutSuggested durationMore than 3 hoursFeatur...
# 4693  AboutSuggested durationMore than 3 hoursFeatur...
#
#                                        Destination_Type Destination_rating  \
# 0     Speciality Museums • Architectural Buildings •...                4.5
# 1     Speciality Museums • Architectural Buildings •...                4.5
# 2     Speciality Museums • Architectural Buildings •...                4.5
# 3     Speciality Museums • Architectural Buildings •...                4.5
# 4     Speciality Museums • Architectural Buildings •...                4.5
# ...                                                 ...                ...
# 4689                     Historic Sites • Ancient Ruins                5.0
# 4690                     Historic Sites • Ancient Ruins                5.0
# 4691                     Historic Sites • Ancient Ruins                5.0
# 4692                     Historic Sites • Ancient Ruins                5.0
# 4693                     Historic Sites • Ancient Ruins                5.0
#
#      Destination_Number_Of_Reviews  \
# 0                   14,097 reviews
# 1                   14,097 reviews
# 2                   14,097 reviews
# 3                   14,097 reviews
# 4                   14,097 reviews
# ...                            ...
# 4689                19,605 reviews
# 4690                19,605 reviews
# 4691                19,605 reviews
# 4692                19,605 reviews
# 4693                19,605 reviews
#
#                                 Destination_Top_Reviews  \
# 0     Consisting of more than 9,000 rooms and spread...
# 1     Consisting of more than 9,000 rooms and spread...
# 2     Consisting of more than 9,000 rooms and spread...
# 3     Consisting of more than 9,000 rooms and spread...
# 4     Consisting of more than 9,000 rooms and spread...
# ...                                                 ...
# 4689  Thank you for visiting Machu Picchu. We hope y...
# 4690  Thank you for visiting Machu Picchu. We hope y...
# 4691  Thank you for visiting Machu Picchu. We hope y...
# 4692  Thank you for visiting Machu Picchu. We hope y...
# 4693  Thank you for visiting Machu Picchu. We hope y...
#
#                        Top_Restaurants
# 0                          Vege Wonder
# 1                        1. King's Joy
# 2     2. Cafe Cha - Shangri-La Beijing
# 3                 3. F Bistronome - FB
# 4                     4. The View 3912
# ...                                ...
# 4689            26. El Mapi Restaurant
# 4690                        27. Ayasqa
# 4691                        28. Cafelu
# 4692             29. Dining Room & Bar
# 4693            30. The Club Inka Wasi
#
# [4694 rows x 16 columns]

# %% [markdown]
# #### Merge the Tourist destinations, Hotels and Restaurants data. The output should be a data frame with 19 attributes

# %%
Destination_hotel_restaurant_df = pd.concat([destination_hotel_attraction_df, destination_restaurant_attraction_df], axis=0)

# %%
Destination_hotel_restaurant_df
# Out:
#      Destination_Name     City Visitors_per_year   Destination_Id  City_Id  \
# 0      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 1      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 2      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 3      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# 4      Forbidden City  Beijing       17,000,000+  g294212-d319086  g294212
# ...               ...      ...               ...              ...      ...
# 4689     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4690     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4691     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4692     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
# 4693     Machu Picchu    Cusco           1411276  g294318-d668949  g294318
#
#      City_Average_Temperature Preferance_Family_Holiday_Destination  \
# 0                         9°C                                    0%
# 1                         9°C                                    0%
# 2                         9°C                                    0%
# 3                         9°C                                    0%
# 4                         9°C                                    0%
# ...                       ...                                   ...
# 4689                     13°C                                    4%
# 4690                     13°C                                    4%
# 4691                     13°C                                    4%
# 4692                     13°C                                    4%
# 4693                     13°C                                    4%
#
#      Preferance_Solo_Trip_Destination Preferance_Friends_Holiday_Destination  \
# 0                                  4%                                     4%
# 1                                  4%                                     4%
# 2                                  4%                                     4%
# 3                                  4%                                     4%
# 4                                  4%                                     4%
# ...                               ...                                    ...
# 4689                              21%                                    13%
# 4690                              21%                                    13%
# 4691                              21%                                    13%
# 4692                              21%                                    13%
# 4693                              21%                                    13%
#
#      Preferance_Spouse/Partner_Holiday_Destination  \
# 0                                               4%
# 1                                               4%
# 2                                               4%
# 3                                               4%
# 4                                               4%
# ...                                            ...
# 4689                                            0%
# 4690                                            0%
# 4691                                            0%
# 4692                                            0%
# 4693                                            0%
#
#                                 Destination_Description  \
# 0     AboutConsisting of more than 9,000 rooms and s...
# 1     AboutConsisting of more than 9,000 rooms and s...
# 2     AboutConsisting of more than 9,000 rooms and s...
# 3     AboutConsisting of more than 9,000 rooms and s...
# 4     AboutConsisting of more than 9,000 rooms and s...
# ...                                                 ...
# 4689  AboutSuggested durationMore than 3 hoursFeatur...
# 4690  AboutSuggested durationMore than 3 hoursFeatur...
# 4691  AboutSuggested durationMore than 3 hoursFeatur...
# 4692  AboutSuggested durationMore than 3 hoursFeatur...
# 4693  AboutSuggested durationMore than 3 hoursFeatur...
#
#                                        Destination_Type Destination_rating  \
# 0     Speciality Museums • Architectural Buildings •...                4.5
# 1     Speciality Museums • Architectural Buildings •...                4.5
# 2     Speciality Museums • Architectural Buildings •...                4.5
# 3     Speciality Museums • Architectural Buildings •...                4.5
# 4     Speciality Museums • Architectural Buildings •...                4.5
# ...                                                 ...                ...
# 4689                     Historic Sites • Ancient Ruins                5.0
# 4690                     Historic Sites • Ancient Ruins                5.0
# 4691                     Historic Sites • Ancient Ruins                5.0
# 4692                     Historic Sites • Ancient Ruins                5.0
# 4693                     Historic Sites • Ancient Ruins                5.0
#
#      Destination_Number_Of_Reviews  \
# 0                   14,097 reviews
# 1                   14,097 reviews
# 2                   14,097 reviews
# 3                   14,097 reviews
# 4                   14,097 reviews
# ...                            ...
# 4689                19,605 reviews
# 4690                19,605 reviews
# 4691                19,605 reviews
# 4692                19,605 reviews
# 4693                19,605 reviews
#
#                                 Destination_Top_Reviews  \
# 0     Consisting of more than 9,000 rooms and spread...
# 1     Consisting of more than 9,000 rooms and spread...
# 2     Consisting of more than 9,000 rooms and spread...
# 3     Consisting of more than 9,000 rooms and spread...
# 4     Consisting of more than 9,000 rooms and spread...
# ...                                                 ...
# 4689  Thank you for visiting Machu Picchu. We hope y...
# 4690  Thank you for visiting Machu Picchu. We hope y...
# 4691  Thank you for visiting Machu Picchu. We hope y...
# 4692  Thank you for visiting Machu Picchu. We hope y...
# 4693  Thank you for visiting Machu Picchu. We hope y...
#
#                                                   Hotel   Hotel_Ratings  \
# 0     Sponsored      Artyzen Habitat Dongzhimen Beijing  5 of 5 bubbles
# 1                      China World Summit Wing, Beijing  5 of 5 bubbles
# 2                                    Shangri-La Beijing  5 of 5 bubbles
# 3                             The Bulgari Hotel Beijing  5 of 5 bubbles
# 4                       Hotel Jen Beijing by Shangri-La  5 of 5 bubbles
# ...                                                 ...             ...
# 4689                                                NaN             NaN
# 4690                                                NaN             NaN
# 4691                                                NaN             NaN
# 4692                                                NaN             NaN
# 4693                                                NaN             NaN
#
#      Hotel_No_of_Reviews         Top_Restaurants
# 0             95 reviews                     NaN
# 1          3,214 reviews                     NaN
# 2          8,489 reviews                     NaN
# 3            255 reviews                     NaN
# 4          2,333 reviews                     NaN
# ...                  ...                     ...
# 4689                 NaN  26. El Mapi Restaurant
# 4690                 NaN              27. Ayasqa
# 4691                 NaN              28. Cafelu
# 4692                 NaN   29. Dining Room & Bar
# 4693                 NaN  30. The Club Inka Wasi
#
# [9080 rows x 19 columns]

# %% [markdown]
# #### Export the scraped data to excel

# %%
Destination_hotel_restaurant_df.to_excel(r'C:\Users\sanyo\OneDrive - Indian School of Business\Term1\DC\Office_Hour\get_phones_data\get_phones_data\Tourist_Destinations_Of_The_World_v4.xlsx',  index = False)
